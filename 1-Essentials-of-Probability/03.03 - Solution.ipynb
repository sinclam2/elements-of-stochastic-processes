# %% [markdown]
# - How would your answer  for 2 change it $\rho_{UV}=0.5$?

# %% [markdown]
# _____
#
# $$
# Var(P) = 0.15x^{2} + 2\cdot0.5\sqrt{0.15\cdot0.2}(x)(1000-x) + 0.2(1000-x)^{2}
# $$

# %% [markdown]
# - Let's plot this

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = 10, 10

# %%
step = 0.01
x = np.arange(0, 1000+step, step)
variances = 0.15*x**2 + 2*0.5*np.sqrt(0.15*0.2)*x*(1000-x) + 0.2*(1000-x)**2

# %%
plt.plot(x, variances)

# %% [markdown]
# - Looks slightly more shifted to the right

# %%
x[np.argmin(variances)]
# Out:
# 641.41

# %% [markdown]
# - Our minimum variance occurs when $x$ is 547.78
#     - Let's confirm this

# %% [markdown]
# $$
# Var(P) = Var\left(xU + (1000-x)V\right) = x^{2}Var(U) + 2x\cdot(1000-x)Cov(U,V) + (1000-x)^{2}Var(V)
# $$

# %% [markdown]
# - Recall: $\rho_{UV} = \frac{Cov(U,V)}{\sqrt{Var(U)Var(V)}} \implies Cov(U,V) = 0.5\cdot\sqrt{0.15\cdot0.2} \approx 0.0866$

# %% [markdown]
# $$
# Var(P) = 0.15x^{2} + 2\cdot0.0866\cdot x \cdot (1000-x) + 0.2(1000-x)^{2} = 0.35x^{2} - 226.795x + 200000
# $$

# %% [markdown]
# - Taking the derivative and setting to zero

# %% [markdown]
# $$
# 2(0.176795)x - 226.795 = 0 \implies x = \frac{226.795}{0.35359} \approx 641.41
# $$
